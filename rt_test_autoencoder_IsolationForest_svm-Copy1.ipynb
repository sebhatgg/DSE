# %% [markdown]
# #####     # Scale the features to [0, 1]
#     scaler = MinMaxScaler()
#     X_scaled = scaler.fit_transform(X_selected)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import IsolationForest
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def hybrid_anomaly_detection():
    # Load data from a CSV file
    #load dataset
    
    data1 = pd.read_csv('rt_test.csv')
    
        
    data = data1.sample(n=50000, random_state=5)
    
    data = data.drop(['proto','service','Attack_type'], axis=1)
    data.dropna(axis=0, inplace=True)

    for column in data.columns:
        data[column] = pd.to_numeric(data[column], errors='coerce')
        
    data.info()
    
    # Preprocessing
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data)
    
#     sns.pairplot(data, kind='scatter')
#     plt.title('Scatter Plot')
#     plt.show()
    
#     X = data.drop('Global_active_power', axis=1)  # Assuming 'target' is the column name of the continuous target variable
#     y_cont = data['Global_active_power']
    
    #convert all the values in the columns into numeric
    for column in data.columns:
        data[column] = pd.to_numeric(data[column], errors='coerce')


#     model = OneClassSVM(kernel='rbf', gamma='auto', nu = 0.2).fit(data)
#     y_pred = model.predict(data)

#     anomaly_values = data.iloc[np.where(y_pred ==-1)]



#     plt.scatter(data["flow_duration"], data["Voltage"])
#     plt.scatter(anomaly_values["flow_duration"],anomaly_values["Voltage"], c="r")
#     plt.show()
    
#     sns.pairplot(data, kind='scatter')
#     plt.title('Scatter Plot')
#     plt.show()
    
    X = data.drop('flow_duration', axis=1)  # Assuming 'label' is your target column
    y_cont = data['flow_duration']

#     # First, binarize `y` based on a chosen threshold.
    y = np.where(y_cont > 20, 1, 0)  # Define `threshold` based on your domain knowledge

    # # Convert continuous target variable to binary labels
    # y = np.where((y_train < 1) | (y_train > 8), 1, 0)

#     # Bin the continuous target variable
#     binner = KBinsDiscretizer(n_bins=n_bins, encode='ordinal', strategy='uniform')
#     y = binner.fit_transform(y_cont.values.reshape(-1, 1)).flatten()

#     # Select top k features; k might be adjusted based on the dataset
#     selector = SelectKBest(f_classif, k=3)
#     X_selected = selector.fit_transform(X, y)
    
    
    
    # Select top k features; you might adjust k based on your dataset
    selector = SelectKBest(f_classif, k=15)
    X_selected = selector.fit_transform(X, y)
    
    X_selected
    

    
    
    
    
    
    
    
    
    

#     # Scale the features
#     scaler = MinMaxScaler()
#     X_scaled = scaler.fit_transform(X_selected)
    
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
    
#         # Feature scaling
#     scaler = StandardScaler()
#     X_train_scaled = scaler.fit_transform(X_train)
#     X_test_scaled = scaler.transform(X_test)
    
    
    #Scale the features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_train)
    
    
    
    # Define and train the autoencoder
    input_dim = X_scaled.shape[1]
    encoding_dim = 32
    input_layer = tf.keras.Input(shape=(input_dim,))
    encoded = layers.Dense(encoding_dim, activation='relu', 
                           activity_regularizer=regularizers.l1(10e-5))(input_layer)
    decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)
    autoencoder = models.Model(input_layer, decoded)
    encoder = models.Model(input_layer, encoded)
    autoencoder.compile(optimizer='adam', loss='mean_squared_error')
    autoencoder.fit(X_scaled, X_scaled, epochs=50, batch_size=256, shuffle=True, validation_split=0.1, verbose=1)

    # Encode the data
    X_train_encoded = encoder.predict(X_train)
    X_test_encoded = encoder.predict(X_test)
    
    # Train Isolation Forest on the encoded data
    iso_forest = IsolationForest(random_state=42)
    iso_forest.fit(X_train_encoded)
    if_train_labels = iso_forest.predict(X_train_encoded)
    
    # Filter only rows detected as normal
    normal_indices = if_train_labels == 1
    X_train_normal = X_train_encoded[normal_indices]
    y_train_normal = y_train[normal_indices]
    
    # Train SVM on the filtered normal data
    svm = SVC(kernel='rbf', gamma='auto', random_state=42)
    svm.fit(X_train_normal, y_train_normal)
    
    # Predict on the entire test dataset
    svm_predictions = svm.predict(X_test_encoded)
    
    # Evaluate the model
    precision = precision_score(y_test, svm_predictions, pos_label=1)
    recall = recall_score(y_test, svm_predictions, pos_label=1)
    f1 = f1_score(y_test, svm_predictions, pos_label=1)
    
    
    print(classification_report(y_test, svm_predictions))

    # Print metrics
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")

    # Confusion Matrix
    cm = confusion_matrix(y_test, svm_predictions, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Anomaly', 'Normal'])
    disp.plot()
    plt.show()

# Example usage, assuming the CSV file is correctly formatted and located
hybrid_anomaly_detection()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 88302 to 73828
# Data columns (total 81 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id.orig_p                 50000 non-null  int64
#  1   id.resp_p                 50000 non-null  int64
#  2   flow_duration             50000 non-null  float64
#  3   fwd_pkts_tot              50000 non-null  int64
#  4   bwd_pkts_tot              50000 non-null  int64
#  5   fwd_data_pkts_tot         50000 non-null  int64
#  6   bwd_data_pkts_tot         50000 non-null  int64
#  7   fwd_pkts_per_sec          50000 non-null  float64
#  8   bwd_pkts_per_sec          50000 non-null  float64
#  9   flow_pkts_per_sec         50000 non-null  float64
#  10  down_up_ratio             50000 non-null  float64
#  11  fwd_header_size_tot       50000 non-null  int64
#  12  fwd_header_size_min       50000 non-null  int64
#  13  fwd_header_size_max       50000 non-null  int64
#  14  bwd_header_size_tot       50000 non-null  int64
#  15  bwd_header_size_min       50000 non-null  int64
#  16  bwd_header_size_max       50000 non-null  int64
#  17  flow_FIN_flag_count       50000 non-null  int64
#  18  flow_SYN_flag_count       50000 non-null  int64
#  19  flow_RST_flag_count       50000 non-null  int64
#  20  fwd_PSH_flag_count        50000 non-null  int64
#  21  bwd_PSH_flag_count        50000 non-null  int64
#  22  flow_ACK_flag_count       50000 non-null  int64
#  23  fwd_URG_flag_count        50000 non-null  int64
#  24  bwd_URG_flag_count        50000 non-null  int64
#  25  flow_CWR_flag_count       50000 non-null  int64
#  26  flow_ECE_flag_count       50000 non-null  int64
#  27  fwd_pkts_payload.min      50000 non-null  int64
#  28  fwd_pkts_payload.max      50000 non-null  int64
#  29  fwd_pkts_payload.tot      50000 non-null  int64
#  30  fwd_pkts_payload.avg      50000 non-null  float64
#  31  fwd_pkts_payload.std      50000 non-null  float64
#  32  bwd_pkts_payload.min      50000 non-null  int64
#  33  bwd_pkts_payload.max      50000 non-null  int64
#  34  bwd_pkts_payload.tot      50000 non-null  int64
#  35  bwd_pkts_payload.avg      50000 non-null  float64
#  36  bwd_pkts_payload.std      50000 non-null  float64
#  37  flow_pkts_payload.min     50000 non-null  int64
#  38  flow_pkts_payload.max     50000 non-null  int64
#  39  flow_pkts_payload.tot     50000 non-null  int64
#  40  flow_pkts_payload.avg     50000 non-null  float64
#  41  flow_pkts_payload.std     50000 non-null  float64
#  42  fwd_iat.min               50000 non-null  float64
#  43  fwd_iat.max               50000 non-null  float64
#  44  fwd_iat.tot               50000 non-null  float64
#  45  fwd_iat.avg               50000 non-null  float64
#  46  fwd_iat.std               50000 non-null  float64
#  47  bwd_iat.min               50000 non-null  float64
#  48  bwd_iat.max               50000 non-null  float64
#  49  bwd_iat.tot               50000 non-null  float64
#  50  bwd_iat.avg               50000 non-null  float64
#  51  bwd_iat.std               50000 non-null  float64
#  52  flow_iat.min              50000 non-null  float64
#  53  flow_iat.max              50000 non-null  float64
#  54  flow_iat.tot              50000 non-null  float64
#  55  flow_iat.avg              50000 non-null  float64
#  56  flow_iat.std              50000 non-null  float64
#  57  payload_bytes_per_second  50000 non-null  float64
#  58  fwd_subflow_pkts          50000 non-null  float64
#  59  bwd_subflow_pkts          50000 non-null  float64
#  60  fwd_subflow_bytes         50000 non-null  float64
#  61  bwd_subflow_bytes         50000 non-null  float64
#  62  fwd_bulk_bytes            50000 non-null  float64
#  63  bwd_bulk_bytes            50000 non-null  float64
#  64  fwd_bulk_packets          50000 non-null  float64
#  65  bwd_bulk_packets          50000 non-null  float64
#  66  fwd_bulk_rate             50000 non-null  float64
#  67  bwd_bulk_rate             50000 non-null  float64
#  68  active.min                50000 non-null  float64
#  69  active.max                50000 non-null  float64
#  70  active.tot                50000 non-null  float64
#  71  active.avg                50000 non-null  float64
#  72  active.std                50000 non-null  float64
#  73  idle.min                  50000 non-null  float64
#  74  idle.max                  50000 non-null  float64
#  75  idle.tot                  50000 non-null  float64
#  76  idle.avg                  50000 non-null  float64
#  77  idle.std                  50000 non-null  float64
#  78  fwd_init_window_size      50000 non-null  int64
#  79  bwd_init_window_size      50000 non-null  int64
#  80  fwd_last_window_size      50000 non-null  int64
# dtypes: float64(47), int64(34)
# memory usage: 31.3 MB
# Epoch 1/50
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [23] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# 141/141 [==============================] - 1s 4ms/step - loss: 0.1336 - val_loss: 0.0441
# Epoch 2/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0228 - val_loss: 0.0135
# Epoch 3/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0073
# Epoch 4/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 5/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 6/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 7/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 8/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 9/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 10/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 11/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 12/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 13/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 14/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 15/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 16/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 17/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 18/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 19/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 20/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 21/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 22/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 23/50
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 24/50
# 141/141 [==============================] - 0s 2ms/step - loss: 9.7894e-04 - val_loss: 0.0010
# Epoch 25/50
# 141/141 [==============================] - 0s 2ms/step - loss: 9.2065e-04 - val_loss: 9.7631e-04
# Epoch 26/50
# 141/141 [==============================] - 0s 2ms/step - loss: 8.6384e-04 - val_loss: 9.1757e-04
# Epoch 27/50
# 141/141 [==============================] - 0s 2ms/step - loss: 8.1241e-04 - val_loss: 8.6202e-04
# Epoch 28/50
# 141/141 [==============================] - 0s 2ms/step - loss: 7.6052e-04 - val_loss: 8.0552e-04
# Epoch 29/50
# 141/141 [==============================] - 0s 2ms/step - loss: 7.1050e-04 - val_loss: 7.5397e-04
# Epoch 30/50
# 141/141 [==============================] - 0s 2ms/step - loss: 6.6408e-04 - val_loss: 7.0456e-04
# Epoch 31/50
# 141/141 [==============================] - 0s 2ms/step - loss: 6.2098e-04 - val_loss: 6.6031e-04
# Epoch 32/50
# 141/141 [==============================] - 0s 2ms/step - loss: 5.8016e-04 - val_loss: 6.1739e-04
# Epoch 33/50
# 141/141 [==============================] - 0s 2ms/step - loss: 5.4139e-04 - val_loss: 5.8186e-04
# Epoch 34/50
# 141/141 [==============================] - 0s 2ms/step - loss: 5.1101e-04 - val_loss: 5.5277e-04
# Epoch 35/50
# 141/141 [==============================] - 0s 2ms/step - loss: 4.8349e-04 - val_loss: 5.2297e-04
# Epoch 36/50
# 141/141 [==============================] - 0s 2ms/step - loss: 4.5644e-04 - val_loss: 4.9741e-04
# Epoch 37/50
# 141/141 [==============================] - 0s 2ms/step - loss: 4.3233e-04 - val_loss: 4.7463e-04
# Epoch 38/50
# 141/141 [==============================] - 0s 3ms/step - loss: 4.0980e-04 - val_loss: 4.5331e-04
# Epoch 39/50
# 141/141 [==============================] - 0s 3ms/step - loss: 3.8967e-04 - val_loss: 4.3601e-04
# Epoch 40/50
# 141/141 [==============================] - 0s 3ms/step - loss: 3.7277e-04 - val_loss: 4.2100e-04
# Epoch 41/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.5919e-04 - val_loss: 4.0856e-04
# Epoch 42/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.4638e-04 - val_loss: 3.9696e-04
# Epoch 43/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.3538e-04 - val_loss: 3.8757e-04
# Epoch 44/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.2601e-04 - val_loss: 3.7860e-04
# Epoch 45/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.1736e-04 - val_loss: 3.7027e-04
# Epoch 46/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.0950e-04 - val_loss: 3.6248e-04
# Epoch 47/50
# 141/141 [==============================] - 0s 2ms/step - loss: 3.0210e-04 - val_loss: 3.5472e-04
# Epoch 48/50
# 141/141 [==============================] - 0s 2ms/step - loss: 2.9525e-04 - val_loss: 3.4773e-04
# Epoch 49/50
# 141/141 [==============================] - 0s 2ms/step - loss: 2.8859e-04 - val_loss: 3.4072e-04
# Epoch 50/50
# 141/141 [==============================] - 0s 2ms/step - loss: 2.8223e-04 - val_loss: 3.3375e-04
# 1250/1250 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      9617
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.96     10000
#    macro avg       0.48      0.50      0.49     10000
# weighted avg       0.92      0.96      0.94     10000
#
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sebha\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
